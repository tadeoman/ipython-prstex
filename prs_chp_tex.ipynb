# %%
# %install_ext http://raw.github.com/tadeoman/ipython-prstex/master/prstex.py
# Out:
# Installed prstex.py. To use it, type:
#   %load_ext prstex

# %%
# %reload_ext prstex

# %%
# %%prstex filename=test
#
# a -> b+
# c & b & d & e -> x-

# %%
# %%chptex filename=testchp
#
# [ a = #{bd}  -> c+
# [] b
# [] c
# ]
